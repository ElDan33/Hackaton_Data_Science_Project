# %% [markdown]
# <a href="https://colab.research.google.com/github/ElDan33/Hackaton_Data_Science_Project/blob/main/Hackaton_TechLayoffs_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 style="color:red"> Proyecto Hackaton-MundosE </h1>

# %% [markdown]
# <img style="width:100%; height:500px; border: 2px solid red" src="https://masterdatascience.online/wp-content/uploads/2020/02/706-1536x1006.jpg.webp"></img>
#
# #### Area temática: *Tecnología*
# #### Tema: *Despidos en las industrias tecnológicas*
#
# **Autor**:
# > Carrizo, Dante Enrique
#
# **Fecha**:
# > 22 de Marzo de 2023

# %%
# Importación de librerías para tratamiento y visualización de datos
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from statistics import mode

# %%
pd.set_option("display.width",None)

# %%
# URL de descarga: https://www.kaggle.com/datasets/salimwid/technology-company-layoffs-20222023-data

# %%
# Lectura del archivo ".csv" y primer exploración del dataset
df = pd.read_csv("D:/Cursos/MundosE/DS/ProyectoIntegrador/tech_layoffs.csv", sep=",")
df.head(10)
# Out:
#             company total_layoffs impacted_workforce_percentage reported_date  \
# 0              C2FO            20                             2     12/9/2022
# 1          VideoAmp       Unclear                             2     9/19/2022
# 2          Amperity            13                             3     8/20/2022
# 3           Addepar            20                             3     1/18/2023
# 4    Thirty Madison            24                             3     5/13/2022
# 5          NextRoll       Unclear                             3      7/8/2022
# 6    Armis Security            25                             4     12/8/2022
# 7           Foxtrot            26                             4     9/23/2022
# 8  Headspace Health            50                             4    12/14/2022
# 9          RealSelf            11                             5     7/21/2022
#
#                         industry headquarter_location  \
# 0              Fintech, payments          Leawood, KS
# 1          Advertising platforms          Los Angeles
# 2                Saas, analytics              Seattle
# 3        fintech, data analytics    Mountain View, CA
# 4                    Health Care             New York
# 5                 Marketing Tech        San Francisco
# 6                  Cybersecurity        San Francisco
# 7  food and beverage, e-commerce              Chicago
# 8           telehealth, wellness          Los Angeles
# 9                    Beauty tech              Seattle
#
#                         sources   status  \
# 0  Kansas City Business Journal  Private
# 1                  Company memo  Private
# 2                      Geekwire  Private
# 3                       Fortune  Private
# 4                         Axios  Private
# 5              Business Insider  Private
# 6                  Calcalistech  Private
# 7              Chicago Business  Private
# 8                     Bloomberg  Private
# 9                      GeekWire  Private
#
#                                     additional_notes
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Per Axios, 22 of the employees laid off were f...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
df.columns
# Out:
# Index(['company', 'total_layoffs', 'impacted_workforce_percentage',
#        'reported_date', 'industry', 'headquarter_location', 'sources',
#        'status', 'additional_notes'],
#       dtype='object')

# %% [markdown]
# ## Descripción de variables
#
#
#
# *   "Company" ---> Nombre de la compañia.
# *   "total_layoffs" ---> Despidos en total.
# *   "impacted_workforce_percentage" ---> % de empleados impactados primer semestre 2022.
# *   "reported_date" ---> Fecha de primer despido o anuncio de despidos.
# *   "industry" ---> Información del segmento en donde opera la compañia.
# *   "headquarter_location" ---> Ubicación de casa matriz.
# *   "sources" ---> Fuente de información.
# *   "status" ---> Si la compañia es pública o privada.
# *   "additional_notes" ---> Detalles extra en los despidos.

# %%
#Forma del dataframe
df.shape
# Out:
# (489, 9)

# %%
# Exploración de la información del dataframe. 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   company                        489 non-null    object
#  1   total_layoffs                  489 non-null    object
#  2   impacted_workforce_percentage  489 non-null    object
#  3   reported_date                  489 non-null    object
#  4   industry                       489 non-null    object
#  5   headquarter_location           489 non-null    object
#  6   sources                        489 non-null    object
#  7   status                         489 non-null    object
#  8   additional_notes               22 non-null     object
# dtypes: object(9)
# memory usage: 34.5+ KB

# %%
# Conteo de valores de variable "industry"
df["industry"].value_counts()
# Out:
# Fintech                       24
# Health Care                   17
# PropTech                      15
# E-commerce                    13
# Cybersecurity                 10
#                               ..
# Enterprise Communication       1
# AI                             1
# Transporation, Logistics       1
# Business development           1
# enterprise tech, analytics     1
# Name: industry, Length: 289, dtype: int64

# %%
# Conteo de valores de variable "status"
df["status"].value_counts()
# Out:
# Private    370
# Public     119
# Name: status, dtype: int64

# %%
# Conteo de valores de variable "headquartes". La mayoria son de USA: Mumbai, india Stockholm, Sweden Ottawa, Canada Tel Aviv 
df["headquarter_location"].unique()[:30]
# Out:
# array(['Leawood, KS', 'Los Angeles', 'Seattle', 'Mountain View, CA',
#        'New York', 'San Francisco', 'Chicago', 'Bay Area, CA',
#        'Mountain View', 'Pittsburgh', 'Boston', 'Miami', 'Mumbai, India',
#        'Torrance, California', 'San Carlos, CA', 'San Diego', 'Detroit',
#        'Bend, Oregon', 'Atlanta', 'Washington, DC', 'Austin',
#        'Distributed', 'Boulder', 'Burlington, MA', 'Bellevue, WA',
#        'Santa Barbara, CA', 'Hamilton, OH', 'San Mateo', 'Waterford, MI',
#        'Stockholm'], dtype=object)

# %% [markdown]
# ### Limpieza de datos

# %%
# Total de datos nulos en el dataset
df.isnull().sum()
# Out:
# company                            0
# total_layoffs                      0
# impacted_workforce_percentage      0
# reported_date                      0
# industry                           0
# headquarter_location               0
# sources                            0
# status                             0
# additional_notes                 467
# dtype: int64

# %%
# Total de datos nulos en la columna "additional_notes"
print(f"{df['additional_notes'].isnull().sum()/df.shape[0]:.2%}")
# Out:
# 95.50%

# %%
# Conteo de valores de variable "total_layoffs"
df["total_layoffs"].value_counts()
# Out:
# Unclear    182
# 100         17
# 30          12
# 40          11
# 150          8
#           ...
# 111          1
# 5000         1
# 64           1
# 262          1
# 9090         1
# Name: total_layoffs, Length: 150, dtype: int64

# %%
#182 compañias no tienen claro el total de despidos. Eliminarlas
df[df["total_layoffs"]=="Unclear"]
# Out:
#               company total_layoffs impacted_workforce_percentage  \
# 1            VideoAmp       Unclear                             2
# 5            NextRoll       Unclear                             3
# 18           Outreach       Unclear                             5
# 19   Boosted Commerce       Unclear                             5
# 20            Forward       Unclear                             5
# ..                ...           ...                           ...
# 464            Starry       Unclear                            74
# 485            Oracle       Unclear                       Unclear
# 486        LivePerson       Unclear                       Unclear
# 487            Skillz       Unclear                       Unclear
# 488         Blueboard       Unclear                       Unclear
#
#     reported_date                   industry headquarter_location  \
# 1       9/19/2022      Advertising platforms          Los Angeles
# 5        7/8/2022             Marketing Tech        San Francisco
# 18       8/2/2022                 Sales Tech              Seattle
# 19      7/25/2022                 E-commerce          Los Angeles
# 20      7/11/2022                Health Care        San Francisco
# ..            ...                        ...                  ...
# 464     1/18/2023             WiFi, hardware               Boston
# 485      8/1/2022  SaaS, enterprise software               Austin
# 486     9/15/2022           Customer service             New York
# 487     8/29/2022        Mobile Apps, Gaming        San Francisco
# 488     11/3/2022        Enterprise Software        San Francisco
#
#                sources   status  \
# 1         Company memo  Private
# 5     Business Insider  Private
# 18            LinkedIn  Private
# 19    Business Insider  Private
# 20   Fierce Healthcare  Private
# ..                 ...      ...
# 464        SEC filings   Public
# 485    The Information   Public
# 486           LinkedIn   Public
# 487      Seeking Alpha   Public
# 488   LinkedIn reports  Private
#
#                                       additional_notes
# 1                                                  NaN
# 5                                                  NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# ..                                                 ...
# 464                                                NaN
# 485  The Information reported thousands of people w...
# 486                                                NaN
# 487                                                NaN
# 488                                                NaN
#
# [182 rows x 9 columns]

# %%
rows_to_drop = df[df['total_layoffs'].str.contains('Unclear')].index
df = df.drop(rows_to_drop)
df
# Out:
#               company total_layoffs impacted_workforce_percentage  \
# 0                C2FO            20                             2
# 2            Amperity            13                             3
# 3             Addepar            20                             3
# 4      Thirty Madison            24                             3
# 6      Armis Security            25                             4
# ..                ...           ...                           ...
# 480         HashiCorp            69                       Unclear
# 481  Quanergy Systems            72                       Unclear
# 482              Doma           825                       Unclear
# 483           Wayfair           870                       Unclear
# 484        Salesforce          9090                       Unclear
#
#     reported_date                             industry headquarter_location  \
# 0       12/9/2022                    Fintech, payments          Leawood, KS
# 2       8/20/2022                      Saas, analytics              Seattle
# 3       1/18/2023              fintech, data analytics    Mountain View, CA
# 4       5/13/2022                          Health Care             New York
# 6       12/8/2022                        Cybersecurity        San Francisco
# ..            ...                                  ...                  ...
# 480     1/11/2023  cybersecurity, cloud infrastructure        San Francisco
# 481    12/14/2022                  Autonomous vehicles        Sunnyvale, CA
# 482     12/6/2022          Insurtech, machine learning        San Francsico
# 483     8/19/2022                   E-commerce, retail               Boston
# 484      1/4/2023           enterprise tech, analytics        San Francisco
#
#                              sources   status  \
# 0       Kansas City Business Journal  Private
# 2                           Geekwire  Private
# 3                            Fortune  Private
# 4                              Axios  Private
# 6                       Calcalistech  Private
# ..                               ...      ...
# 480        Crunchbase News Reporting   Public
# 481  Silicon Valley Business Journal   Public
# 482                             Doma   Public
# 483                     Boston Globe   Public
# 484                   New York Times   Public
#
#                                       additional_notes
# 0                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Per Axios, 22 of the employees laid off were f...
# 6                                                  NaN
# ..                                                 ...
# 480                                                NaN
# 481                                                NaN
# 482    The company previously laid off workers in May.
# 483                                                NaN
# 484                                                NaN
#
# [307 rows x 9 columns]

# %%
#67 compañias no tienen claro el total de % impactado, reemplazarlos por 0
df[df["impacted_workforce_percentage"]=="Unclear"]
# Out:
#               company total_layoffs impacted_workforce_percentage  \
# 260       100 Thieves            12                       Unclear
# 261             Orbit            14                       Unclear
# 262        Cybereason           100                       Unclear
# 263        Progrexion           100                       Unclear
# 264               Gem           100                       Unclear
# ..                ...           ...                           ...
# 480         HashiCorp            69                       Unclear
# 481  Quanergy Systems            72                       Unclear
# 482              Doma           825                       Unclear
# 483           Wayfair           870                       Unclear
# 484        Salesforce          9090                       Unclear
#
#     reported_date                             industry headquarter_location  \
# 260     1/10/2023                       eSports, Media          Los Angeles
# 261     8/12/2022                Productivity software        San Francisco
# 262      6/1/2022                        Cybersecurity               Boston
# 263      6/7/2022                              FinTech       Salt Lake City
# 264     11/2/2022                           Recruiting        San Francisco
# ..            ...                                  ...                  ...
# 480     1/11/2023  cybersecurity, cloud infrastructure        San Francisco
# 481    12/14/2022                  Autonomous vehicles        Sunnyvale, CA
# 482     12/6/2022          Insurtech, machine learning        San Francsico
# 483     8/19/2022                   E-commerce, retail               Boston
# 484      1/4/2023           enterprise tech, analytics        San Francisco
#
#                              sources   status  \
# 260                          Dexerto  Private
# 261          Orbit CEO Patrick Woods  Private
# 262                            CTech  Private
# 263                  Crunchbase News  Private
# 264                          Gem CEO  Private
# ..                               ...      ...
# 480        Crunchbase News Reporting   Public
# 481  Silicon Valley Business Journal   Public
# 482                             Doma   Public
# 483                     Boston Globe   Public
# 484                   New York Times   Public
#
#                                       additional_notes
# 260  More than a dozen employees were reportedly la...
# 261  Orbit CEO Patrick Woods announced at least 14 ...
# 262  Affected employees are in U.S., Israel, and Eu...
# 263                                                NaN
# 264                                                NaN
# ..                                                 ...
# 480                                                NaN
# 481                                                NaN
# 482    The company previously laid off workers in May.
# 483                                                NaN
# 484                                                NaN
#
# [67 rows x 9 columns]

# %%
df["impacted_workforce_percentage"].replace("Unclear",0, inplace = True)

# %%
# Transformar el df al tipo de formato correspondiente
df["total_layoffs"]=df["total_layoffs"].astype(int)
df["impacted_workforce_percentage"]=df["impacted_workforce_percentage"].astype(float)

# %%
# Eliminación de la columna "additional_notes" debido a que
df.drop("additional_notes", axis=1, inplace=True)
df.head()
# Out:
#           company  total_layoffs  impacted_workforce_percentage reported_date  \
# 0            C2FO             20                            2.0     12/9/2022
# 2        Amperity             13                            3.0     8/20/2022
# 3         Addepar             20                            3.0     1/18/2023
# 4  Thirty Madison             24                            3.0     5/13/2022
# 6  Armis Security             25                            4.0     12/8/2022
#
#                   industry headquarter_location                       sources  \
# 0        Fintech, payments          Leawood, KS  Kansas City Business Journal
# 2          Saas, analytics              Seattle                      Geekwire
# 3  fintech, data analytics    Mountain View, CA                       Fortune
# 4              Health Care             New York                         Axios
# 6            Cybersecurity        San Francisco                  Calcalistech
#
#     status
# 0  Private
# 2  Private
# 3  Private
# 4  Private
# 6  Private

# %% [markdown]
# ### Features del dataset

# %%
# Trabajo con fechas

df['reported_date'] = pd.to_datetime(df['reported_date'], format="%m/%d/%Y")

# Descomposición de las fechas.
df['Month'] = df['reported_date'].dt.month
df['Year'] = df['reported_date'].dt.year
df['Day'] = df['reported_date'].dt.day
df['Week_Day'] = df['reported_date'].dt.strftime("%A")

def day_int(x):
    if x <= 5:
        return 'Begin'
    elif x >=24:
        return 'End'
    else:
        return 'Middle'

df['Dem_Int'] = df['Day'].apply(lambda x: day_int(x))
df.head()
# Out:
#           company  total_layoffs  impacted_workforce_percentage reported_date  \
# 0            C2FO             20                            2.0    2022-12-09
# 2        Amperity             13                            3.0    2022-08-20
# 3         Addepar             20                            3.0    2023-01-18
# 4  Thirty Madison             24                            3.0    2022-05-13
# 6  Armis Security             25                            4.0    2022-12-08
#
#                   industry headquarter_location                       sources  \
# 0        Fintech, payments          Leawood, KS  Kansas City Business Journal
# 2          Saas, analytics              Seattle                      Geekwire
# 3  fintech, data analytics    Mountain View, CA                       Fortune
# 4              Health Care             New York                         Axios
# 6            Cybersecurity        San Francisco                  Calcalistech
#
#     status  Month  Year  Day   Week_Day Dem_Int
# 0  Private     12  2022    9     Friday  Middle
# 2  Private      8  2022   20   Saturday  Middle
# 3  Private      1  2023   18  Wednesday  Middle
# 4  Private      5  2022   13     Friday  Middle
# 6  Private     12  2022    8   Thursday  Middle

# %%
df.Year.unique()
# Out:
# array([2022, 2023], dtype=int64)

# %%
# Creación de empleados totales teniendo en cuenta el % de empleados afectados por layoffs
df["Empleados_totales"]=round((df["total_layoffs"]*100)/df["impacted_workforce_percentage"],2)
df.head()
# Out:
#           company  total_layoffs  impacted_workforce_percentage reported_date  \
# 0            C2FO             20                            2.0    2022-12-09
# 2        Amperity             13                            3.0    2022-08-20
# 3         Addepar             20                            3.0    2023-01-18
# 4  Thirty Madison             24                            3.0    2022-05-13
# 6  Armis Security             25                            4.0    2022-12-08
#
#                   industry headquarter_location                       sources  \
# 0        Fintech, payments          Leawood, KS  Kansas City Business Journal
# 2          Saas, analytics              Seattle                      Geekwire
# 3  fintech, data analytics    Mountain View, CA                       Fortune
# 4              Health Care             New York                         Axios
# 6            Cybersecurity        San Francisco                  Calcalistech
#
#     status  Month  Year  Day   Week_Day Dem_Int  Empleados_totales
# 0  Private     12  2022    9     Friday  Middle            1000.00
# 2  Private      8  2022   20   Saturday  Middle             433.33
# 3  Private      1  2023   18  Wednesday  Middle             666.67
# 4  Private      5  2022   13     Friday  Middle             800.00
# 6  Private     12  2022    8   Thursday  Middle             625.00

# %%
# Verificando si el tipo de datos de las columnas es numérico o no
from pandas.api.types import is_numeric_dtype

num_cols = ['total_layoffs','impacted_workforce_percentage']
cols = df.columns
for i in cols:
    if is_numeric_dtype(df[i]) == False:
        print(i)
# Out:
# company
# reported_date
# industry
# headquarter_location
# sources
# status
# Week_Day
# Dem_Int

# %%
# Formateo de la columna "industry"
ind = []
for i in df['industry'].to_list():
    ind.append(i.split(' ')[-1])
    
ind = [x.title() for x in ind]
ind = [x.replace("-", "") for x in ind]

df['industry'] = ind
print(df['industry'].unique())
# Out:
# ['Payments' 'Analytics' 'Care' 'Cybersecurity' 'ECommerce' 'Wellness'
#  'Tech' 'Software' 'Crypto' 'Transportation' 'Ecommerce' 'Logistics'
#  'Cryptocurrency' 'Productivity' 'Insurtech' 'Games' 'Fintech' 'Retail'
#  'Robotics' 'Finance' 'Cannabis' 'Ar' 'Media/Entertainment' 'Journalism'
#  'Media' 'Saas' 'Learning' 'Enterprise' 'Security' 'Processing' 'Proptech'
#  'Crowdfunding' 'Automation' 'Transfer' 'Intelligence' 'Creators'
#  'Collection' 'Recruiting' 'Marketplace' 'Infrastructure' 'Gaming'
#  'Marketing' 'Storage' 'Energy' 'Edtech' 'Ai' 'Services' 'Banking' 'News'
#  'Blockchain' 'Apis' 'Communication' 'Development' 'Benefits'
#  'Verification' 'Telehealth' 'Iot' 'Fitness' 'Transporation' 'Beverage'
#  'Event' 'Hospitality' 'Diagnostics' 'Estate' 'Beauty' 'Health' 'Travel'
#  'Hotels' 'Surveillance' 'Trials' 'Advertising' 'Events' 'Service'
#  'Automotive' 'Api' 'Network' 'It' 'Management' 'Music' 'Streaming'
#  'Computing' 'Biotech' 'Tools' 'Hosting' 'Pharmaceuticals' 'Delivery'
#  'Insurance' 'Pens' 'Wireless' 'Systems' 'Foodtech' 'Fashion' 'Vehicles']

# %%
# Formateo de la columna "headquarter_location"
ind = []
for i in df['headquarter_location'].to_list():
    ind.append(i.split(',')[-1])
    
ind = [x.upper() for x in ind]
ind = [x.replace("-", "") for x in ind]

df['headquarter_location'] = ind

# %%
df
# Out:
#               company  total_layoffs  impacted_workforce_percentage  \
# 0                C2FO             20                            2.0
# 2            Amperity             13                            3.0
# 3             Addepar             20                            3.0
# 4      Thirty Madison             24                            3.0
# 6      Armis Security             25                            4.0
# ..                ...            ...                            ...
# 480         HashiCorp             69                            NaN
# 481  Quanergy Systems             72                            NaN
# 482              Doma            825                            NaN
# 483           Wayfair            870                            NaN
# 484        Salesforce           9090                            NaN
#
#     reported_date        industry headquarter_location  \
# 0      2022-12-09        Payments                   KS
# 2      2022-08-20       Analytics              SEATTLE
# 3      2023-01-18       Analytics                   CA
# 4      2022-05-13            Care             NEW YORK
# 6      2022-12-08   Cybersecurity        SAN FRANCISCO
# ..            ...             ...                  ...
# 480    2023-01-11  Infrastructure        SAN FRANCISCO
# 481    2022-12-14        Vehicles                   CA
# 482    2022-12-06        Learning        SAN FRANCSICO
# 483    2022-08-19          Retail               BOSTON
# 484    2023-01-04       Analytics        SAN FRANCISCO
#
#                              sources   status  Month  Year  Day   Week_Day  \
# 0       Kansas City Business Journal  Private     12  2022    9     Friday
# 2                           Geekwire  Private      8  2022   20   Saturday
# 3                            Fortune  Private      1  2023   18  Wednesday
# 4                              Axios  Private      5  2022   13     Friday
# 6                       Calcalistech  Private     12  2022    8   Thursday
# ..                               ...      ...    ...   ...  ...        ...
# 480        Crunchbase News Reporting   Public      1  2023   11  Wednesday
# 481  Silicon Valley Business Journal   Public     12  2022   14  Wednesday
# 482                             Doma   Public     12  2022    6    Tuesday
# 483                     Boston Globe   Public      8  2022   19     Friday
# 484                   New York Times   Public      1  2023    4  Wednesday
#
#     Dem_Int  Empleados_totales
# 0    Middle            1000.00
# 2    Middle             433.33
# 3    Middle             666.67
# 4    Middle             800.00
# 6    Middle             625.00
# ..      ...                ...
# 480  Middle                NaN
# 481  Middle                NaN
# 482  Middle                NaN
# 483  Middle                NaN
# 484   Begin                NaN
#
# [307 rows x 14 columns]

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307 entries, 0 to 484
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   company                        307 non-null    object
#  1   total_layoffs                  307 non-null    int32
#  2   impacted_workforce_percentage  240 non-null    float64
#  3   reported_date                  307 non-null    datetime64[ns]
#  4   industry                       307 non-null    object
#  5   headquarter_location           307 non-null    object
#  6   sources                        307 non-null    object
#  7   status                         307 non-null    object
#  8   Month                          307 non-null    int64
#  9   Year                           307 non-null    int64
#  10  Day                            307 non-null    int64
#  11  Week_Day                       307 non-null    object
#  12  Dem_Int                        307 non-null    object
#  13  Empleados_totales              240 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(3), object(7)
# memory usage: 34.8+ KB

# %%
despidos_totales=df["total_layoffs"].sum()
print(f"Despidos totales = ",  despidos_totales)
total_empleados=df["Empleados_totales"].sum()
print(f"Empleados_totales = ",  total_empleados)
print(f"Porcentaje total de despidos industria tech = {despidos_totales/total_empleados:.2%}")
# Out:
# Despidos totales =  138156
# Empleados_totales =  906245.66
# Porcentaje total de despidos industria tech = 15.24%

# %%
df3 =(df.groupby("industry")[["total_layoffs","Empleados_totales"]].sum()).sort_values("total_layoffs", ascending=False).reset_index()
df3["%_de_despidos"]=round((df3["total_layoffs"]/df3["Empleados_totales"])*100,2)
df3.head(20)
# Out:
#           industry  total_layoffs  Empleados_totales  %_de_despidos
# 0             Saas          22342          443420.00           5.04
# 1            Media          16367           97846.61          16.73
# 2         Software          13311           61414.29          21.67
# 3         Services          12176            1380.00         882.32
# 4          Fintech          10594           34022.35          31.14
# 5        Analytics           9572            5324.76         179.76
# 6        Ecommerce           6220           38690.47          16.08
# 7        ECommerce           4571           17449.80          26.20
# 8          Fitness           4486            1648.57         272.11
# 9         Proptech           4233           21345.60          19.83
# 10  Transportation           2606           25513.34          10.21
# 11            Care           2480            7823.91          31.70
# 12          Crypto           2340            6718.41          34.83
# 13   Cybersecurity           1821           13836.11          13.16
# 14          Retail           1454            4533.33          32.07
# 15  Cryptocurrency           1263            5551.93          22.75
# 16        Learning           1113            1708.00          65.16
# 17       Insurtech           1113            4033.89          27.59
# 18          Health           1095               0.00            inf
# 19         Biotech           1025             277.78         369.00

# %%
df5 =(df.groupby("headquarter_location")[["total_layoffs","Empleados_totales"]].sum()).sort_values("total_layoffs", ascending=False).reset_index()
df5["%_de_despidos"]=round((df5["total_layoffs"]/df5["Empleados_totales"])*100,2)
df5.head(20)
# Out:
#    headquarter_location  total_layoffs  Empleados_totales  %_de_despidos
# 0                    CA          32155          213316.56          15.07
# 1         SAN FRANCISCO          30745          113512.22          27.09
# 2               SEATTLE          30477          387646.78           7.86
# 3              NEW YORK          15583           36007.25          43.28
# 4                 TEMPE           4000               0.00            inf
# 5          PHILADELPHIA           2300               0.00            inf
# 6               CHICAGO           1840           11345.75          16.22
# 7                BOSTON           1661            6967.07          23.84
# 8           LOS ANGELES           1123            5774.02          19.45
# 9            MENLO PARK           1114            3170.70          35.13
# 10              ATLANTA           1113            5032.74          22.12
# 11            SAN DIEGO           1061            1400.00          75.79
# 12               CANADA           1000           10000.00          10.00
# 13             COLUMBUS            933            1167.50          79.91
# 14            PALO ALTO            880            5804.57          15.16
# 15                MIAMI            840           16125.00           5.21
# 16        SAN FRANCSICO            825               0.00            inf
# 17                   CT            760            2000.00          38.00
# 18            STOCKHOLM            750            6250.00          12.00
# 19                   MO            700           23333.33           3.00

# %%
df['total_layoffs'].describe()
# Out:
# count      307.000000
# mean       450.019544
# std       1652.123678
# min          5.000000
# 25%         44.000000
# 50%         95.000000
# 75%        200.000000
# max      18000.000000
# Name: total_layoffs, dtype: float64

# %%
# Inspeccionamos el comportamiento de la columna "total_layoffs"
plt.figure(figsize=(10,8))
sns.kdeplot(x=df['total_layoffs'])
plt.title('Number of Layoffs')
plt.show()

# %%
# Exploración de Total de Despidos
df.boxplot("total_layoffs", figsize=(12,7))
# Out:
# <AxesSubplot:>

# %%
# CREACIOÓN DE FUNCIÓN DE VISUALIZACIÓN DE DATOS RESÚMEN
def imagen_0(dte,column,title):
    """
    Gráfico de disperción 

    """
    # ------------- Configuración de Figura
    figura = plt.figure(figsize=(15,8))
    figura.suptitle(title, fontsize=30, color='grey')
    figura.subplots_adjust(hspace=0.3)
    tamanio = (2,2)
    dt = dte.copy()
    # Eliminación de datos "Unclear". 
    dt = dt.replace('Unclear',None).dropna().reset_index(drop=True).astype(int)
    bbox = dict(boxstyle='round', facecolor='white', alpha=0.5)
    # -------------- Box -==================================
    ## Ax 
    pos = (0,0)
    ax1 = plt.subplot2grid(tamanio, pos,colspan=2)

    ## Plot
    box = sns.boxplot(
      orient='h',
      x = dt.values,
      ax= ax1,
      width = 0.3,
      boxprops= {"facecolor": (.4, .6, .8, .5), "edgecolor": "grey", "linewidth": 0.5}, # Color del box y color de los bordes del box
      whiskerprops={"color": "grey", "linewidth": 0.5}, # Color de las lineas encima y abajo de q1 e q3
      capprops={"color": "grey", "linewidth": 0.5}, # Color de la barra limite 
      medianprops={"color": "grey", "linewidth": 0.5} # Propiedades de la mediana
    )

    box.set_title('Gráfico de cajas',horizontalalignment='left', x=0,fontsize=16,color='grey')

    ## Configuración
    quantiles = dt.quantile([0.25, 0.75]).values.tolist()
    LI = quantiles[0] - ((quantiles[1] - quantiles[0])*1.5)
    LS = quantiles[1] + ((quantiles[1] - quantiles[0])*1.5)
    if LI < dt.min():
        LI = dt.min()
    if LS > dt.max():
        LS = dt.max()

    text = f"Lim. Inf. = {LI}\n50% range [{quantiles[0]} => {quantiles[1]}]\nLim. Sup. = {LS}"
    box.annotate(text, xy=(dt.max()/2, -0.2), fontsize=13, color='black', horizontalalignment='center', bbox=bbox)
    box.set_xlabel('Valores', horizontalalignment='left', x=0, fontsize=10, color='black')
    box.spines['top'].set_visible(False)
    box.spines['right'].set_visible(False)
    box.spines['left'].set_color('darkgrey')
    box.spines['bottom'].set_color('darkgrey')
    box.tick_params(axis='both', colors='darkgrey')    
    
    # -------------- Histograma ==================================
    ## Ax 
    pos = (1,0)
    ax2 = plt.subplot2grid(tamanio, pos,colspan=2)

    ## Plot
    hist = sns.histplot(
            x = dt.values,
            ax = ax2,
            bins=20,
            color='skyblue',
            stat="density",
    )
    sns.kdeplot(data=dt, color='red')

    hist.spines['top'].set_visible(False)
    hist.spines['right'].set_visible(False)
    hist.spines['left'].set_color('darkgrey')
    hist.spines['bottom'].set_color('darkgrey')
    hist.tick_params(axis='both', colors='darkgrey')

    hist.set_xlabel(column, horizontalalignment='left', x=0, fontsize=10, color='black')

    hist.set_title('Histograma',horizontalalignment='left', x=0, fontsize=16,color='grey')
    return plt.show()
    
       
def bar_company(dte,title,hm):
    dt = dte.copy()
    plt.figure(figsize=(15,5))
    dt['total_layoffs'] = dt['total_layoffs'].replace('Unclear',None)
    dt = dt[['company','total_layoffs']].dropna().reset_index(drop=True)
    dt['total_layoffs'] = dt['total_layoffs'].astype(int) 
    dt = pd.DataFrame(dt.groupby(['company'])['total_layoffs'].sum()).sort_values(by='total_layoffs',ascending=False)
    
    fig = sns.barplot( x=dt['total_layoffs'][:hm], y=dt.index[:hm], palette='flare_r')
    for n,i in enumerate(fig.patches):
        x = i.get_width()
        if n > 3:
            k = 1.02
        else:
            k = 1
        fig.annotate(x,
                    xy = (x*k, n),
                    horizontalalignment='left',
                    verticalalignment='center')
        
    fig.set_title(title, fontsize=30, color='dimgrey',horizontalalignment='left', x=0, y=1.05)   
    fig.tick_params(axis='x', colors='darkgrey')
    return plt.show()

def bar_field(dte,title, hm):
    dt = dte.copy()
    plt.figure(figsize=(15,5))
    dt['total_layoffs'] = dt['total_layoffs'].replace('Unclear',None)
    dt = dt[['industry','total_layoffs']].dropna().reset_index(drop=True)
    dt['total_layoffs'] = dt['total_layoffs'].astype(int) 
    dt = pd.DataFrame(dt.groupby(['industry'])['total_layoffs'].sum()).sort_values(by='total_layoffs',ascending=False)
    
    fig = sns.barplot( x=dt['total_layoffs'][:hm], y=dt.index[:hm], palette='rocket')
    for n,i in enumerate(fig.patches):
        x = i.get_width()
        if n > 3:
            k = 1.02
        else:
            k = 1
        fig.annotate(x,
                    xy = (x*k, n),
                    horizontalalignment='left',
                    verticalalignment='center')
        
    fig.set_title(title, fontsize=30, color='dimgrey',horizontalalignment='left', x=0, y=1.05)   
    fig.tick_params(axis='x', colors='darkgrey')
    return plt.show()

def bar_sourc(dte,title,hm):
    dt = dte.copy()
    plt.figure(figsize=(15,5))
    dt = dt['sources'].value_counts()[:hm]
    
    fig = sns.barplot( x=dt.values, y=dt.index, palette='rocket')
    
    for n,i in enumerate(fig.patches):
        x = i.get_width()
        if n > 3:
            k = 1.02
        else:
            k = 1
        fig.annotate(x,
                    xy = (x*k, n),
                    horizontalalignment='left',
                    verticalalignment='center')

    fig.set_title(title, fontsize=30, color='dimgrey',horizontalalignment='left', x=0, y=1.05)   
    fig.tick_params(axis='x', colors='darkgrey')
    return plt.show()

def bar_loc(dte,title,hm):
    dt = dte.copy()
    plt.figure(figsize=(15,5))
    dt = dt['headquarter_location'].value_counts()[:hm]
    
    fig = sns.barplot( x=dt.values, y=dt.index, palette='rocket')
    
    for n,i in enumerate(fig.patches):
        x = i.get_width()
        if n > 3:
            k = 1.02
        else:
            k = 1
        fig.annotate(x,
                    xy = (x*k, n),
                    horizontalalignment='left',
                    verticalalignment='center')

    fig.set_title(title, fontsize=30, color='dimgrey',horizontalalignment='left', x=0, y=1.05)   
    fig.tick_params(axis='x', colors='darkgrey')
    return plt.show()

def typ_loc(dtc, title):
    dt = dtc.copy()
    tamanio = (1,2)
    figura = plt.figure(figsize=(20,7))
    figura.suptitle(title, fontsize=24, color='dimgrey') 
    
    # ----------
    pos = (0,0)
    ax = plt.subplot2grid(tamanio, pos)
    vc = dt['status']
    fig = sns.countplot(x =dt['status'],palette='Greens')
    for n,i in enumerate(fig.patches):
        x = i.get_height()
        if n > 3:
            k = 1.02
        else:
            k = 1
        fig.annotate(x,
                    xy = (n, x),
                    horizontalalignment='center',
                    verticalalignment='bottom', size=15)    
    fig.set_ylim([0, 500])
    fig.tick_params(left=False, labelleft=False)
    fig.set_xlabel('')
    fig.set_title('Estado', x=0, color='grey', horizontalalignment='left')
    # ----------
    pos = (0,1)
    ax = plt.subplot2grid(tamanio, pos)
    vc = dt['headquarter_location'].value_counts()[:10]
    fig = sns.barplot(y = vc.index, x = vc.values, palette='GnBu')
    for n,i in enumerate(fig.patches):
        x = i.get_width()
        if n > 3:
            k = 1.02
        else:
            k = 1
        fig.annotate(int(x),
                    xy = (x*k, n),
                    horizontalalignment='left',
                    verticalalignment='center')
    fig.set_xlim([0, 155])
    fig.tick_params(bottom=False, labelbottom=False)
    fig.set_title('Ciudades', x=0, color='grey', horizontalalignment='left')
    fig.set_xlabel('Conteo')
    return plt.show()


def time_vis(dtc,title):
    figura = plt.figure(figsize=(15,20))
    figura.subplots_adjust(hspace=0.3, wspace=0.3)
    dt = dtc.copy()
    tamanio = (4,2)
    rows=2
    cols=2
    figura.suptitle(title, fontsize=30, color='dimgrey', y=0.96) 
    cs = ['Year','Month','Week_Day','Dem_Int']
    c = 0
    for row in range(rows):
        for col in range(cols):
            df_t = dt[cs[c]].value_counts()
            pos = (row,col)
            ax = plt.subplot2grid(tamanio, pos)

            fig = sns.barplot(x = df_t.index, y = df_t.values, ax = ax, palette = 'Reds')
            fig.set_title(cs[c], x=0, color='grey', horizontalalignment='left')
            fig.set_ylim([0,df_t.values.max()*1.1])
            c+=1
            for n,i in enumerate(fig.patches):
                y = i.get_height()
                fig.annotate(int(y),
                            xy = (n, y),
                            horizontalalignment='center',
                            verticalalignment='bottom')
            
    # ----------------
    
    dte = dtc.copy()
    dte['reported_date'] = dte['reported_date'].dt.to_period('M')
    dte = dte.sort_values(by='reported_date').set_index('reported_date')

    dtee = dte.groupby(['reported_date'])['company'].count()
    
    pos = (2,0)
    ax = plt.subplot2grid(tamanio, pos, colspan=2)
    
    fig = sns.lineplot(x=dtee.index.astype(str), y=dtee.values, color='r')
    fig.set_title('Conteo de despidos publicadas por mes', x=0, color='grey', horizontalalignment='left')
    fig.set_ylabel('Conteo')
    fig.set_xlabel('Fechas')
# --------------

    dte = dtc.copy()
    dte['total_layoffs'] = dte['total_layoffs'].replace('Unclear',None)
    dte = dte[['total_layoffs','reported_date']].dropna().reset_index(drop=True)
    dte['total_layoffs'] = dte['total_layoffs'].astype(int)
    dte['reported_date'] = dte['reported_date'].dt.to_period('M')
    dte = dte.sort_values(by='reported_date').set_index('reported_date')

    dte = dte.groupby(['reported_date'])['total_layoffs'].sum()
    pos = (3,0)
    ax = plt.subplot2grid(tamanio, pos, colspan=2)
    
    fig = sns.lineplot(x=dte.index.astype(str), y=dte.values, color='r')     
    fig.set_title('Numero total de despidos anunciadas por mes', x=0, color='grey', horizontalalignment='left')
    fig.set_ylabel('Sumatoria')
    fig.set_xlabel('Fecha')
    return plt.show()

# %%
# Exploración de los despidos por compañias, de mayor a menor
company_layoffs = (df.groupby(["company"])["total_layoffs"].sum()).sort_values(ascending=False)

# Grafico de barras 
plt.figure(figsize=(12,100))
ax = sns.barplot(x=company_layoffs, y=company_layoffs.index, orient="h")
ax.tick_params(top=True, labeltop=True, bottom=True, labelbottom=True)
ax.set_xlabel("Total de despidos")
ax.set_title("Total de despidos por compañía")
for i in ax.containers:
    ax.bar_label(i,)
ax.grid()

# %%
df4 =(df.groupby("company")[["total_layoffs","Empleados_totales"]].sum()).sort_values("total_layoffs", ascending=False).reset_index()
df4["%_de_despidos"]=round((df4["total_layoffs"]/df4["Empleados_totales"])*100,2)
df4.head(20)
# Out:
#        company  total_layoffs  Empleados_totales  %_de_despidos
# 0       Amazon          18000          360000.00            5.0
# 1     Alphabet          12000               0.00            inf
# 2         Meta          11000           84615.38           13.0
# 3    Microsoft          10000               0.00            inf
# 4   Salesforce           9090               0.00            inf
# 5   Better.com           5000           10000.00           50.0
# 6        Cisco           4100           82000.00            5.0
# 7      Peloton           4084               0.00            inf
# 8      Carvana           4000               0.00            inf
# 9      Twitter           3740            5342.86           70.0
# 10      Gopuff           2300               0.00            inf
# 11    Coinbase           2110            4906.98           43.0
# 12      Redfin           1332            7010.53           19.0
# 13        Snap           1280            6400.00           20.0
# 14    DoorDash           1250           20833.33            6.0
# 15      Kraken           1100            3666.67           30.0
# 16        Noom           1095               0.00            inf
# 17      Stripe           1050               0.00            inf
# 18   Robinhood           1013            3069.70           33.0
# 19     Shopify           1000           10000.00           10.0

# %%
# Gráfica del estado del sector y las ciudades más relevantes
typ_loc(df,'Estado y Localización')

# %%
# Gráfico de la distribución de los despidos totales en gráfico de cajas y por histograma con densidad
imagen_0(df['total_layoffs'], 'Despidos Totales','Distribution of informed layoffs')

# %%
# Gráfica de la distribución de la fuerza de trabajo afectada
imagen_0(df['impacted_workforce_percentage'], 'Fuerza de trabajo afectada(%)','Distribucion de la fuerza de trabajo afectada %')

# %%
# Gráfico de barras de las 20 compañías con más despidos
bar_company(df, 'Top 20 de compañías con más despidos',20)

# %%
# Gráfico de barras de las 20 industrias con más despidos
bar_field(df,'Top 20 Industries with the Most Informed Layoffs', 20)

# %%
# Gráfico de barras de las 20 localizaciones con más despidos
bar_loc(df,'Top 20 Headquarter localization with most Layoffs', 20)

# %%
# Gráfico de barras con las 20 fuentes donde más se anunciaron despidos
bar_sourc(df,'Top 20 Sources',20)

# %%
# Análisis temporal de los despidos, por año, por mes, por día de semana, la altura del mes,
# y el conteo y la sumatoria de los despidos en el tiempo.
time_vis(df,'Time Series Analysis')

# %%
# Exploración de la distribución de las variables
sns.pairplot(df, corner=True, diag_kind="kde")

# %% [markdown]
# ## Creación de Modelo de ML

# %%
# Importación de los módulos necesarios para nuestro/s modelo/s de ML
from sklearn.preprocessing import OrdinalEncoder, StandardScaler, PolynomialFeatures, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, r2_score,classification_report, confusion_matrix

# %%
# Se realiza una copia del dataframe original para no pisarlo
df_copy = df.copy()
df_copy.head()
# Out:
#           company  total_layoffs  impacted_workforce_percentage reported_date  \
# 0            C2FO             20                            2.0    2022-12-09
# 2        Amperity             13                            3.0    2022-08-20
# 3         Addepar             20                            3.0    2023-01-18
# 4  Thirty Madison             24                            3.0    2022-05-13
# 6  Armis Security             25                            4.0    2022-12-08
#
#         industry headquarter_location                       sources   status  \
# 0       Payments                   KS  Kansas City Business Journal  Private
# 2      Analytics              SEATTLE                      Geekwire  Private
# 3      Analytics                   CA                       Fortune  Private
# 4           Care             NEW YORK                         Axios  Private
# 6  Cybersecurity        SAN FRANCISCO                  Calcalistech  Private
#
#    Month  Year  Day   Week_Day Dem_Int  Empleados_totales
# 0     12  2022    9     Friday  Middle            1000.00
# 2      8  2022   20   Saturday  Middle             433.33
# 3      1  2023   18  Wednesday  Middle             666.67
# 4      5  2022   13     Friday  Middle             800.00
# 6     12  2022    8   Thursday  Middle             625.00

# %%
# Creación de un dataframe que contenga los despidos totales por compañía y ordenados de mayor a menor
df_layoffs_num = (df_copy.groupby(["company","total_layoffs"]).sum()).sort_values(by=["total_layoffs","impacted_workforce_percentage"], 
                                                                                    ascending=False).reset_index()
df_layoffs_num = df_layoffs_num.drop("Empleados_totales", axis=1)
df_layoffs_num
# Out:
#                     company  total_layoffs  impacted_workforce_percentage  \
# 0                    Amazon          18000                            5.0
# 1                  Alphabet          12000                            0.0
# 2                      Meta          11000                           13.0
# 3                 Microsoft          10000                            0.0
# 4                Salesforce           9090                            0.0
# ..                      ...            ...                            ...
# 302             100 Thieves             12                            0.0
# 303                RealSelf             11                            5.0
# 304  Digital Currency Group             10                           13.0
# 305             Sourcepoint              7                           13.0
# 306                   Woven              5                           15.0
#
#      Month  Year  Day
# 0        1  2023    5
# 1        1  2023   20
# 2       11  2022    9
# 3        1  2023   18
# 4        1  2023    4
# ..     ...   ...  ...
# 302      1  2023   10
# 303      7  2022   21
# 304     11  2022    2
# 305      6  2022    2
# 306      8  2022   16
#
# [307 rows x 6 columns]

# %%
# Creación de un dataframe que contenga sólo las columnas NO numéricas.
df_layoffs_cat = df_copy.select_dtypes(["object","datetime"])
df_layoffs_cat
# Out:
#               company reported_date        industry headquarter_location  \
# 0                C2FO    2022-12-09        Payments                   KS
# 2            Amperity    2022-08-20       Analytics              SEATTLE
# 3             Addepar    2023-01-18       Analytics                   CA
# 4      Thirty Madison    2022-05-13            Care             NEW YORK
# 6      Armis Security    2022-12-08   Cybersecurity        SAN FRANCISCO
# ..                ...           ...             ...                  ...
# 480         HashiCorp    2023-01-11  Infrastructure        SAN FRANCISCO
# 481  Quanergy Systems    2022-12-14        Vehicles                   CA
# 482              Doma    2022-12-06        Learning        SAN FRANCSICO
# 483           Wayfair    2022-08-19          Retail               BOSTON
# 484        Salesforce    2023-01-04       Analytics        SAN FRANCISCO
#
#                              sources   status   Week_Day Dem_Int
# 0       Kansas City Business Journal  Private     Friday  Middle
# 2                           Geekwire  Private   Saturday  Middle
# 3                            Fortune  Private  Wednesday  Middle
# 4                              Axios  Private     Friday  Middle
# 6                       Calcalistech  Private   Thursday  Middle
# ..                               ...      ...        ...     ...
# 480        Crunchbase News Reporting   Public  Wednesday  Middle
# 481  Silicon Valley Business Journal   Public  Wednesday  Middle
# 482                             Doma   Public    Tuesday  Middle
# 483                     Boston Globe   Public     Friday  Middle
# 484                   New York Times   Public  Wednesday   Begin
#
# [307 rows x 8 columns]

# %%
# Combinación de ambos dataframe en un sólo marco de datos con los datos ordenados según el total de despidos y la fuerza de trabajo afectada
df_layoffs_merged = pd.merge(df_layoffs_num, df_layoffs_cat, on=["company"])
df_layoffs_merged
# Out:
#                     company  total_layoffs  impacted_workforce_percentage  \
# 0                    Amazon          18000                            5.0
# 1                  Alphabet          12000                            0.0
# 2                      Meta          11000                           13.0
# 3                 Microsoft          10000                            0.0
# 4                Salesforce           9090                            0.0
# ..                      ...            ...                            ...
# 308             100 Thieves             12                            0.0
# 309                RealSelf             11                            5.0
# 310  Digital Currency Group             10                           13.0
# 311             Sourcepoint              7                           13.0
# 312                   Woven              5                           15.0
#
#      Month  Year  Day reported_date        industry headquarter_location  \
# 0        1  2023    5    2023-01-05            Saas              SEATTLE
# 1        1  2023   20    2023-01-20        Services                   CA
# 2       11  2022    9    2022-11-09           Media                   CA
# 3        1  2023   18    2023-01-18        Software              SEATTLE
# 4        1  2023    4    2023-01-04       Analytics        SAN FRANCISCO
# ..     ...   ...  ...           ...             ...                  ...
# 308      1  2023   10    2023-01-10           Media          LOS ANGELES
# 309      7  2022   21    2022-07-21            Tech              SEATTLE
# 310     11  2022    2    2022-11-02  Cryptocurrency                   CT
# 311      6  2022    2    2022-06-02            Tech             NEW YORK
# 312      8  2022   16    2022-08-16      Recruiting         INDIANAPOLIS
#
#                        sources   status   Week_Day Dem_Int
# 0          Wall Street Journal   Public   Thursday   Begin
# 1                         CNBC   Public     Friday  Middle
# 2                         CNBC   Public  Wednesday  Middle
# 3                    Microsoft   Public  Wednesday  Middle
# 4               New York Times   Public  Wednesday   Begin
# ..                         ...      ...        ...     ...
# 308                    Dexerto  Private    Tuesday  Middle
# 309                   GeekWire  Private   Thursday  Middle
# 310                   Coindesk  Private  Wednesday   Begin
# 311  Crunchbase News reporting  Private   Thursday   Begin
# 312                      AdAge  Private    Tuesday  Middle
#
# [313 rows x 13 columns]

# %%
# Creación de una función que me categorice el riesgo en Alto, Medio y Bajo en función del total de despidos.
def categorize_risk(row):
    if row["total_layoffs"] < 60:
        return "Bajo"
    elif row["total_layoffs"] < 150:
        return "Medio"
    else:
        return "Alto"

df_layoffs_merged["Risk_Category"] = df_layoffs_merged.apply(categorize_risk, axis=1)

# %%
# Inspeccion de los cambios en el dataframe
df_layoffs_merged
# Out:
#                     company  total_layoffs  impacted_workforce_percentage  \
# 0                    Amazon          18000                            5.0
# 1                  Alphabet          12000                            0.0
# 2                      Meta          11000                           13.0
# 3                 Microsoft          10000                            0.0
# 4                Salesforce           9090                            0.0
# ..                      ...            ...                            ...
# 308             100 Thieves             12                            0.0
# 309                RealSelf             11                            5.0
# 310  Digital Currency Group             10                           13.0
# 311             Sourcepoint              7                           13.0
# 312                   Woven              5                           15.0
#
#      Month  Year  Day reported_date        industry headquarter_location  \
# 0        1  2023    5    2023-01-05            Saas              SEATTLE
# 1        1  2023   20    2023-01-20        Services                   CA
# 2       11  2022    9    2022-11-09           Media                   CA
# 3        1  2023   18    2023-01-18        Software              SEATTLE
# 4        1  2023    4    2023-01-04       Analytics        SAN FRANCISCO
# ..     ...   ...  ...           ...             ...                  ...
# 308      1  2023   10    2023-01-10           Media          LOS ANGELES
# 309      7  2022   21    2022-07-21            Tech              SEATTLE
# 310     11  2022    2    2022-11-02  Cryptocurrency                   CT
# 311      6  2022    2    2022-06-02            Tech             NEW YORK
# 312      8  2022   16    2022-08-16      Recruiting         INDIANAPOLIS
#
#                        sources   status   Week_Day Dem_Int Risk_Category
# 0          Wall Street Journal   Public   Thursday   Begin          Alto
# 1                         CNBC   Public     Friday  Middle          Alto
# 2                         CNBC   Public  Wednesday  Middle          Alto
# 3                    Microsoft   Public  Wednesday  Middle          Alto
# 4               New York Times   Public  Wednesday   Begin          Alto
# ..                         ...      ...        ...     ...           ...
# 308                    Dexerto  Private    Tuesday  Middle          Bajo
# 309                   GeekWire  Private   Thursday  Middle          Bajo
# 310                   Coindesk  Private  Wednesday   Begin          Bajo
# 311  Crunchbase News reporting  Private   Thursday   Begin          Bajo
# 312                      AdAge  Private    Tuesday  Middle          Bajo
#
# [313 rows x 14 columns]

# %%
df_layoffs_merged["Risk_Category"].value_counts()
# Out:
# Medio    106
# Alto     104
# Bajo     103
# Name: Risk_Category, dtype: int64

# %% [markdown]
# ### Modelo de Clasificación con RandomForest

# %%
# Separación de las variables independientes y la dependiente
training_data = df_layoffs_merged[["industry", "total_layoffs", "status", "Risk_Category"]]
training_data = pd.get_dummies(training_data, columns=["industry","status"])
X_train, X_test, y_train, y_test = train_test_split(training_data.drop("Risk_Category", axis=1), training_data["Risk_Category"], test_size=0.2, random_state=42)

# %%
# Instanciación del objeto RandomForestClassifier y entrenamiento del modelo
model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, random_state=42)

# %%
# Predicción con los datos de entrenamiento
y_train_pred = model.predict(X_train)
print(y_train_pred)
# Out:
# ['Alto' 'Bajo' 'Bajo' 'Medio' 'Medio' 'Bajo' 'Medio' 'Alto' 'Bajo' 'Alto'
#  'Medio' 'Alto' 'Alto' 'Bajo' 'Alto' 'Medio' 'Medio' 'Medio' 'Bajo' 'Bajo'
#  'Bajo' 'Bajo' 'Medio' 'Bajo' 'Alto' 'Medio' 'Medio' 'Alto' 'Alto' 'Medio'
#  'Alto' 'Alto' 'Medio' 'Medio' 'Alto' 'Bajo' 'Alto' 'Alto' 'Medio' 'Medio'
#  'Alto' 'Alto' 'Bajo' 'Alto' 'Alto' 'Alto' 'Bajo' 'Bajo' 'Alto' 'Medio'
#  'Alto' 'Alto' 'Medio' 'Medio' 'Bajo' 'Medio' 'Alto' 'Medio' 'Alto' 'Bajo'
#  'Medio' 'Alto' 'Bajo' 'Medio' 'Bajo' 'Bajo' 'Medio' 'Bajo' 'Medio'
#  'Medio' 'Medio' 'Medio' 'Bajo' 'Alto' 'Bajo' 'Medio' 'Medio' 'Medio'
#  'Medio' 'Medio' 'Bajo' 'Bajo' 'Medio' 'Bajo' 'Bajo' 'Alto' 'Medio'
#  'Medio' 'Bajo' 'Medio' 'Bajo' 'Bajo' 'Medio' 'Alto' 'Alto' 'Alto' 'Bajo'
#  'Medio' 'Bajo' 'Medio' 'Medio' 'Medio' 'Bajo' 'Alto' 'Medio' 'Medio'
#  'Bajo' 'Medio' 'Alto' 'Alto' 'Alto' 'Medio' 'Medio' 'Medio' 'Medio'
#  'Medio' 'Alto' 'Medio' 'Bajo' 'Medio' 'Bajo' 'Alto' 'Alto' 'Bajo' 'Medio'
#  'Alto' 'Bajo' 'Medio' 'Bajo' 'Alto' 'Bajo' 'Bajo' 'Alto' 'Medio' 'Bajo'
#  'Alto' 'Medio' 'Medio' 'Alto' 'Alto' 'Medio' 'Bajo' 'Bajo' 'Bajo' 'Alto'
#  'Bajo' 'Medio' 'Bajo' 'Alto' 'Bajo' 'Alto' 'Medio' 'Alto' 'Bajo' 'Medio'
#  'Bajo' 'Bajo' 'Medio' 'Alto' 'Bajo' 'Medio' 'Medio' 'Bajo' 'Alto' 'Alto'
#  'Bajo' 'Alto' 'Alto' 'Bajo' 'Medio' 'Alto' 'Medio' 'Bajo' 'Bajo' 'Medio'
#  'Alto' 'Bajo' 'Medio' 'Alto' 'Bajo' 'Medio' 'Bajo' 'Alto' 'Bajo' 'Bajo'
#  'Bajo' 'Medio' 'Alto' 'Alto' 'Alto' 'Bajo' 'Bajo' 'Bajo' 'Medio' 'Medio'
#  'Alto' 'Bajo' 'Medio' 'Bajo' 'Alto' 'Alto' 'Alto' 'Alto' 'Alto' 'Medio'
#  'Alto' 'Bajo' 'Alto' 'Alto' 'Bajo' 'Bajo' 'Alto' 'Alto' 'Bajo' 'Medio'
#  'Bajo' 'Medio' 'Bajo' 'Bajo' 'Alto' 'Alto' 'Medio' 'Medio' 'Bajo' 'Medio'
#  'Medio' 'Alto' 'Alto' 'Bajo' 'Bajo' 'Alto' 'Medio' 'Bajo' 'Medio' 'Bajo'
#  'Bajo' 'Medio' 'Bajo' 'Medio' 'Alto' 'Alto' 'Bajo' 'Medio' 'Bajo' 'Alto'
#  'Medio' 'Alto' 'Medio' 'Bajo' 'Alto']

# %%
# Asertividad con los datos de entrenamiento
train_accuracy = accuracy_score(y_train, y_train_pred)
print(f"Train Set accuracy Score: {train_accuracy}")
# Out:
# Train Set accuracy Score: 0.988

# %%
# Testeo con nuevos datos, en este caso una muestra de los datos de prueba.
new_data = X_test.sample(1)
pred_prueba = model.predict(new_data)
pred_prueba
# Out:
# array(['Alto'], dtype=object)

# %%
# Predicción con los datos de prueba
y_test_pred = model.predict(X_test)
print(y_test_pred)
# Out:
# ['Alto' 'Alto' 'Medio' 'Medio' 'Medio' 'Alto' 'Bajo' 'Medio' 'Bajo' 'Bajo'
#  'Medio' 'Alto' 'Medio' 'Bajo' 'Bajo' 'Alto' 'Alto' 'Medio' 'Alto' 'Bajo'
#  'Alto' 'Bajo' 'Bajo' 'Medio' 'Medio' 'Alto' 'Medio' 'Medio' 'Alto' 'Bajo'
#  'Bajo' 'Alto' 'Alto' 'Medio' 'Alto' 'Alto' 'Bajo' 'Medio' 'Alto' 'Medio'
#  'Alto' 'Medio' 'Alto' 'Medio' 'Medio' 'Bajo' 'Bajo' 'Bajo' 'Alto' 'Bajo'
#  'Alto' 'Medio' 'Alto' 'Bajo' 'Alto' 'Alto' 'Medio' 'Medio' 'Medio'
#  'Medio' 'Bajo' 'Bajo' 'Bajo']

# %%
# Asertividad con los datos de prueba
test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"Test Set accurady score: {test_accuracy}")
# Out:
# Test Set accurady score: 0.9841269841269841

# %%
# Visualización de la matriz de confusión del set de entrenamiento.
sns.heatmap(confusion_matrix(y_train, y_train_pred), annot=True, cmap='PuBu', fmt='0.0f', linewidths=0.25, 
           annot_kws={'size':13} )
plt.xlabel('Predichos')
plt.ylabel('Reales')
plt.title("Métricas del set de entrenamiento")

print(f'Accuracy del modelo de {model.__class__.__name__} : {accuracy_score(y_train, y_train_pred):.2f}')
print(f'Rporte del modelo de {model.__class__.__name__}:\n {classification_report(y_train, y_train_pred)}')
# Out:
# Accuracy del modelo de RandomForestClassifier : 0.99
# Rporte del modelo de RandomForestClassifier:
#                precision    recall  f1-score   support
#
#         Alto       0.99      0.98      0.98        81
#         Bajo       1.00      1.00      1.00        84
#        Medio       0.98      0.99      0.98        85
#
#     accuracy                           0.99       250
#    macro avg       0.99      0.99      0.99       250
# weighted avg       0.99      0.99      0.99       250

# %%
# Visualización de la matriz de confusión del set de prueba.
sns.heatmap(confusion_matrix(y_test, y_test_pred), annot=True, cmap='PuBu', fmt='0.0f', linewidths=0.25, 
           annot_kws={'size':13} )
plt.xlabel('Predichos')
plt.ylabel('Reales')
plt.title("Métricas del set de pruebas")

print(f'Accuracy del modelo de {model.__class__.__name__} : {accuracy_score(y_test, y_test_pred):.2f}')
print(f'Rporte del modelo de {model.__class__.__name__}:\n {classification_report(y_test, y_test_pred)}')
# Out:
# Accuracy del modelo de RandomForestClassifier : 0.98
# Rporte del modelo de RandomForestClassifier:
#                precision    recall  f1-score   support
#
#         Alto       1.00      0.96      0.98        23
#         Bajo       1.00      1.00      1.00        19
#        Medio       0.95      1.00      0.98        21
#
#     accuracy                           0.98        63
#    macro avg       0.98      0.99      0.98        63
# weighted avg       0.98      0.98      0.98        63

# %% [markdown]
# ### Optimizando nuestro modelo de clasificación con GridSearch

# %%
# Creación de grilla de parámetros
params = {
  "n_estimators":[50,100,500],
  "max_depth":[5,10,20],
  "min_samples_split":[5,7,10],
  "criterion":["gini","entropy","log_loss"]
}

# Creación de objeto GridSearchCV
grid = GridSearchCV(model, params, cv=5)

# %%
# Entrenamiento de la grilla
grid.fit(X_train, y_train)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 135 fits failed out of a total of 405.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 450, in fit
#     trees = Parallel(
#   File "D:\Anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "D:\Anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "D:\Anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "D:\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "D:\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "D:\Anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "D:\Anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "D:\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "D:\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 185, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "D:\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "D:\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# D:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.908 0.888 0.892 0.908 0.892 0.888 0.908 0.892 0.888 0.944 0.944 0.944
#  0.948 0.944 0.948 0.948 0.944 0.948 0.96  0.952 0.964 0.964 0.952 0.976
#  0.96  0.96  0.972 0.908 0.888 0.888 0.912 0.888 0.884 0.912 0.888 0.884
#  0.948 0.948 0.944 0.952 0.948 0.948 0.948 0.948 0.948 0.96  0.952 0.96
#  0.956 0.952 0.96  0.964 0.952 0.968   nan   nan   nan   nan   nan   nan
#    nan   nan   nan   nan   nan   nan   nan   nan   nan   nan   nan   nan
#    nan   nan   nan   nan   nan   nan   nan   nan   nan]
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(max_depth=5, random_state=42),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [5, 10, 20],
#                          'min_samples_split': [5, 7, 10],
#                          'n_estimators': [50, 100, 500]})

# %%
# Mejor puntaje de la grilla
grid.best_score_
# Out:
# 0.976

# %%
# Mejores parámetros de la grilla
grid.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 20,
#  'min_samples_split': 7,
#  'n_estimators': 500}

# %%
# Creación de un nuevo modelo RandomForestClassifier pero con los parámetros con mejor rendimiento en el GridSearch.
optimized_rfc = RandomForestClassifier(criterion="gini", max_depth=20, min_samples_split=7, n_estimators=500)
optimized_rfc.fit(X_train, y_train)

# Predicción y Asertividad del set de entrenamiento.
y_train_pred_optimized  = optimized_rfc.predict(X_train)
y_train_accuracy_optimized = accuracy_score(y_train, y_train_pred_optimized)
y_train_accuracy_optimized
# Out:
# 1.0

# %%
# Visualización de la matriz de confusión del set de entrenamiento del RandomForestClassifier optimizado.
sns.heatmap(confusion_matrix(y_train, y_train_pred_optimized), annot=True, cmap='PuBu', fmt='0.0f', linewidths=0.25, 
           annot_kws={'size':13} )
plt.xlabel('Predichos')
plt.ylabel('Reales')
plt.title("Métricas del set de entrenamiento optimizado")

print(f'Accuracy del modelo de {model.__class__.__name__} optimizado: {accuracy_score(y_train, y_train_pred_optimized):.2f}')
print(f'Rporte del modelo de {model.__class__.__name__} optimizado:\n {classification_report(y_train, y_train_pred_optimized)}')
# Out:
# Accuracy del modelo de RandomForestClassifier optimizado: 1.00
# Rporte del modelo de RandomForestClassifier optimizado:
#                precision    recall  f1-score   support
#
#         Alto       1.00      1.00      1.00        81
#         Bajo       1.00      1.00      1.00        84
#        Medio       1.00      1.00      1.00        85
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250

# %%
# Predicción y Asertividad del set de prueba.
y_test_pred_optimized  = optimized_rfc.predict(X_test)
y_test_accuracy_optimized = accuracy_score(y_test, y_test_pred_optimized)
y_test_accuracy_optimized
# Out:
# 1.0

# %%
# Visualización de la matriz de confusión del set de prueba del RandomForestClassifier optimizado.
sns.heatmap(confusion_matrix(y_test, y_test_pred_optimized), annot=True, cmap='PuBu', fmt='0.0f', linewidths=0.25, 
           annot_kws={'size':13} )
plt.xlabel('Predichos')
plt.ylabel('Reales')
plt.title("Métricas del set de pruebas optimizado")

print(f'Accuracy del modelo de {model.__class__.__name__} optimizado: {accuracy_score(y_test, y_test_pred_optimized):.2f}')
print(f'Rporte del modelo de {model.__class__.__name__} optimizado:\n {classification_report(y_test, y_test_pred_optimized)}')
# Out:
# Accuracy del modelo de RandomForestClassifier optimizado: 1.00
# Rporte del modelo de RandomForestClassifier optimizado:
#                precision    recall  f1-score   support
#
#         Alto       1.00      1.00      1.00        23
#         Bajo       1.00      1.00      1.00        19
#        Medio       1.00      1.00      1.00        21
#
#     accuracy                           1.00        63
#    macro avg       1.00      1.00      1.00        63
# weighted avg       1.00      1.00      1.00        63

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# #### PROBANDO MODELO DE CLASIFICACIÓN CON DATOS IMPUTADOS CON MEDIANA

# %% [markdown]
# ##### Carga de datos y exploración

# %%
datos = pd.read_csv('./Downloads/tech_layoffs.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 datos = pd.read_csv('./Downloads/tech_layoffs.csv')
#
# NameError: name 'pd' is not defined

# %%
datos.head()
# Out:
#           company total_layoffs impacted_workforce_percentage reported_date  \
# 0            C2FO            20                             2     12/9/2022
# 1        VideoAmp       Unclear                             2     9/19/2022
# 2        Amperity            13                             3     8/20/2022
# 3         Addepar            20                             3     1/18/2023
# 4  Thirty Madison            24                             3     5/13/2022
#
#                   industry headquarter_location                       sources  \
# 0        Fintech, payments          Leawood, KS  Kansas City Business Journal
# 1    Advertising platforms          Los Angeles                  Company memo
# 2          Saas, analytics              Seattle                      Geekwire
# 3  fintech, data analytics    Mountain View, CA                       Fortune
# 4              Health Care             New York                         Axios
#
#     status                                   additional_notes
# 0  Private                                                NaN
# 1  Private                                                NaN
# 2  Private                                                NaN
# 3  Private                                                NaN
# 4  Private  Per Axios, 22 of the employees laid off were f...

# %% [markdown]
# ##### Limpieza y reemplazo de valores

# %%
datos.drop("additional_notes", axis=1, inplace=True)

# %%
datos["total_layoffs"] = datos["total_layoffs"].apply(lambda x: None if x == "Unclear" else x)
datos["impacted_workforce_percentage"] = datos["impacted_workforce_percentage"].apply(lambda x: None if x == "Unclear" else x)

# %%
datos
# Out:
#             company total_layoffs impacted_workforce_percentage reported_date  \
# 0              C2FO            20                             2     12/9/2022
# 1          VideoAmp          None                             2     9/19/2022
# 2          Amperity            13                             3     8/20/2022
# 3           Addepar            20                             3     1/18/2023
# 4    Thirty Madison            24                             3     5/13/2022
# ..              ...           ...                           ...           ...
# 484      Salesforce          9090                          None      1/4/2023
# 485          Oracle          None                          None      8/1/2022
# 486      LivePerson          None                          None     9/15/2022
# 487          Skillz          None                          None     8/29/2022
# 488       Blueboard          None                          None     11/3/2022
#
#                        industry headquarter_location  \
# 0             Fintech, payments          Leawood, KS
# 1         Advertising platforms          Los Angeles
# 2               Saas, analytics              Seattle
# 3       fintech, data analytics    Mountain View, CA
# 4                   Health Care             New York
# ..                          ...                  ...
# 484  enterprise tech, analytics        San Francisco
# 485   SaaS, enterprise software               Austin
# 486            Customer service             New York
# 487         Mobile Apps, Gaming        San Francisco
# 488         Enterprise Software        San Francisco
#
#                           sources   status
# 0    Kansas City Business Journal  Private
# 1                    Company memo  Private
# 2                        Geekwire  Private
# 3                         Fortune  Private
# 4                           Axios  Private
# ..                            ...      ...
# 484                New York Times   Public
# 485               The Information   Public
# 486                      LinkedIn   Public
# 487                 Seeking Alpha   Public
# 488              LinkedIn reports  Private
#
# [489 rows x 8 columns]

# %% [markdown]
# ##### Imputamos valores por la mediana de las variables

# %%
# Rellenamos los datos anteriormente convertidos a "None" por la medianas de las respectivas columnas
layoffs_median = int(datos["total_layoffs"].median())
impacted_wfp_median = int(datos["impacted_workforce_percentage"].median())

datos["total_layoffs"] = datos["total_layoffs"].fillna(layoffs_median)
datos["impacted_workforce_percentage"] = datos["impacted_workforce_percentage"].fillna(impacted_wfp_median)

# Convertimos los datos de "total_layoffs" y "impacted_workforce_percentage" de Object a Float
datos["total_layoffs"] = datos["total_layoffs"].astype("float64")
datos["impacted_workforce_percentage"] = datos["impacted_workforce_percentage"].astype("float64")

# %%
datos.total_layoffs.describe()
# Out:
# count      489.000000
# mean       317.885481
# std       1319.488455
# min          5.000000
# 25%         73.000000
# 50%         95.000000
# 75%        120.000000
# max      18000.000000
# Name: total_layoffs, dtype: float64

# %% [markdown]
# ##### Cambiamos el formato de columnas categóricas

# %%
# Formateamos la columna "industry"
ind = []
for i in datos['industry'].to_list():
    ind.append(i.split(' ')[-1])
    
ind = [x.title() for x in ind]
ind = [x.replace("-", "") for x in ind]

datos['industry'] = ind
print(df['industry'].unique())

# Formateamos la columna "headquarter_location"
ind = []
for i in datos['headquarter_location'].to_list():
    ind.append(i.split(',')[-1])
    
ind = [x.upper() for x in ind]
ind = [x.replace("-", "") for x in ind]

datos['headquarter_location'] = ind
# Out:
# ['Payments' 'Analytics' 'Care' 'Cybersecurity' 'ECommerce' 'Wellness'
#  'Tech' 'Software' 'Crypto' 'Transportation' 'Ecommerce' 'Logistics'
#  'Cryptocurrency' 'Productivity' 'Insurtech' 'Games' 'Fintech' 'Retail'
#  'Robotics' 'Finance' 'Cannabis' 'Ar' 'Media/Entertainment' 'Journalism'
#  'Media' 'Saas' 'Learning' 'Enterprise' 'Security' 'Processing' 'Proptech'
#  'Crowdfunding' 'Automation' 'Transfer' 'Intelligence' 'Creators'
#  'Collection' 'Recruiting' 'Marketplace' 'Infrastructure' 'Gaming'
#  'Marketing' 'Storage' 'Energy' 'Edtech' 'Ai' 'Services' 'Banking' 'News'
#  'Blockchain' 'Apis' 'Communication' 'Development' 'Benefits'
#  'Verification' 'Telehealth' 'Iot' 'Fitness' 'Transporation' 'Beverage'
#  'Event' 'Hospitality' 'Diagnostics' 'Estate' 'Beauty' 'Health' 'Travel'
#  'Hotels' 'Surveillance' 'Trials' 'Advertising' 'Events' 'Service'
#  'Automotive' 'Api' 'Network' 'It' 'Management' 'Music' 'Streaming'
#  'Computing' 'Biotech' 'Tools' 'Hosting' 'Pharmaceuticals' 'Delivery'
#  'Insurance' 'Pens' 'Wireless' 'Systems' 'Foodtech' 'Fashion' 'Vehicles']

# %% [markdown]
# ##### Damos un poco de estilo a las fechas

# %%
# Trabajamos con fechas

datos['reported_date'] = pd.to_datetime(datos['reported_date'], format="%m/%d/%Y")
# Let's decompose the date.
datos['Month'] = datos['reported_date'].dt.month
datos['Year'] = datos['reported_date'].dt.year
datos['Day'] = datos['reported_date'].dt.day
datos['Week_Day'] = datos['reported_date'].dt.strftime("%A")

def day_int(x):
    if x <= 5:
        return 'Begin'
    elif x >=24:
        return 'End'
    else:
        return 'Middle'

datos['Dem_Int'] = datos['Day'].apply(lambda x: day_int(x))

# %% [markdown]
# ##### Inspeccionamos el comportamiento de la variable de interés

# %%
# Inspeccionamos el comportamiento de la columna "total_layoffs"
plt.figure(figsize=(10,8))
sns.kdeplot(x=datos['total_layoffs'])
plt.title('Number of Layoffs')
plt.show()

# %%
# Exploración de Total de Despidos
datos.boxplot("total_layoffs", figsize=(12,7))
# Out:
# <AxesSubplot:>

# %%
# Exploración de la distribución de la fuerza de trabajo afectada
datos.boxplot("impacted_workforce_percentage", figsize=(12,7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Generamos una columna categórica discretizando el rango de despidos por compañia

# %%
# Creación de una función que me categorice el riesgo en Alto, Medio y Bajo en función del total de despidos.
def categorize_risk(row):
    if row["total_layoffs"] <= 100:
        return "Bajo"
    elif row["total_layoffs"] <= 500:
        return "Medio"
    else:
        return "Alto"

datos["Risk_Category"] = datos.apply(categorize_risk, axis=1)

# %%
datos.head()
# Out:
#    company  total_layoffs  impacted_workforce_percentage reported_date  \
# 0       73           20.0                            2.0    2022-12-09
# 1      442           95.0                            2.0    2022-09-19
# 2       23           13.0                            3.0    2022-08-20
# 3        7           20.0                            3.0    2023-01-18
# 4      416           24.0                            3.0    2022-05-13
#
#    industry headquarter_location                       sources  status  Month  \
# 0        88                   KS  Kansas City Business Journal       0     12
# 1        91          LOS ANGELES                  Company memo       0      9
# 2         4              SEATTLE                      Geekwire       0      8
# 3         4                   CA                       Fortune       0      1
# 4        20             NEW YORK                         Axios       0      5
#
#    Year  Day   Week_Day Dem_Int  Risk_Category
# 0  2022    9     Friday  Middle              1
# 1  2022   19     Monday  Middle              1
# 2  2022   20   Saturday  Middle              1
# 3  2023   18  Wednesday  Middle              1
# 4  2022   13     Friday  Middle              1

# %% [markdown]
# ##### Separamos las variables en conjunto de entrenamiento y prueba

# %%
# Separación de las variables independientes y la dependiente
training_data = datos[["industry","total_layoffs", "status", "Risk_Category"]]
training_data = pd.get_dummies(training_data, columns=["industry","status"])
X_train, X_test, y_train, y_test = train_test_split(training_data.drop("Risk_Category", axis=1), training_data["Risk_Category"], test_size=0.2, random_state=42)

# %% [markdown]
# ##### Implementamos nuestro modelo RandomForest para clasificación

# %%
# Creación de un nuevo modelo RandomForestClassifier pero con los parámetros con mejor rendimiento en el GridSearch.
optimized_rfc = RandomForestClassifier(criterion="gini", max_depth=20, min_samples_split=7, n_estimators=500)
optimized_rfc.fit(X_train, y_train)

# Predicción y Asertividad del set de entrenamiento.
y_train_pred_optimized  = optimized_rfc.predict(X_train)
y_train_accuracy_optimized = accuracy_score(y_train, y_train_pred_optimized)
y_train_accuracy_optimized
# Out:
# 1.0

# %% [markdown]
# ##### Evaluamos el rendimiento del set de entrenamiento

# %%
# Visualización de la matriz de confusión del set de entrenamiento del RandomForestClassifier optimizado.
sns.heatmap(confusion_matrix(y_train, y_train_pred_optimized), annot=True, cmap='PuBu', fmt='0.0f', linewidths=0.25, 
           annot_kws={'size':13} )
plt.xlabel('Predichos')
plt.ylabel('Reales')
plt.title("Métricas del set de entrenamiento optimizado")

print(f'Accuracy del modelo de {optimized_rfc.__class__.__name__} optimizado: {accuracy_score(y_train, y_train_pred_optimized):.2f}')
print(f'Rporte del modelo de {optimized_rfc.__class__.__name__} optimizado:\n {classification_report(y_train, y_train_pred_optimized)}')
# Out:
# Accuracy del modelo de RandomForestClassifier optimizado: 1.00
# Rporte del modelo de RandomForestClassifier optimizado:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        24
#            1       1.00      1.00      1.00       287
#            2       1.00      1.00      1.00        80
#
#     accuracy                           1.00       391
#    macro avg       1.00      1.00      1.00       391
# weighted avg       1.00      1.00      1.00       391

# %% [markdown]
# ##### Evaluamos el rendimiento del set de prueba

# %%
# Predicción y Asertividad del set de prueba.
y_test_pred_optimized  = optimized_rfc.predict(X_test)
y_test_accuracy_optimized = accuracy_score(y_test, y_test_pred_optimized)
y_test_accuracy_optimized
# Out:
# 0.9795918367346939

# %%
# Visualización de la matriz de confusión del set de prueba del RandomForestClassifier optimizado.
sns.heatmap(confusion_matrix(y_test, y_test_pred_optimized), annot=True, cmap='PuBu', fmt='0.0f', linewidths=0.25, 
           annot_kws={'size':13} )
plt.xlabel('Predichos')
plt.ylabel('Reales')
plt.title("Métricas del set de pruebas optimizado")

print(f'Accuracy del modelo de {optimized_rfc.__class__.__name__} optimizado: {accuracy_score(y_test, y_test_pred_optimized):.2f}')
print(f'Rporte del modelo de {optimized_rfc.__class__.__name__} optimizado:\n {classification_report(y_test, y_test_pred_optimized)}')
# Out:
# Accuracy del modelo de RandomForestClassifier optimizado: 0.98
# Rporte del modelo de RandomForestClassifier optimizado:
#                precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93        15
#            1       1.00      1.00      1.00        68
#            2       0.88      1.00      0.94        15
#
#     accuracy                           0.98        98
#    macro avg       0.96      0.96      0.96        98
# weighted avg       0.98      0.98      0.98        98
